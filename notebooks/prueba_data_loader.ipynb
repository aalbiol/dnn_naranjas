# %%
# %load_ext autoreload
# %autoreload 2
from dataLoad import  FruitDataModule
import torch

# %%
datamodule = FruitDataModule(train_set_folder = '/home/aalbiol/reanotado_3_clases_con_Sara/train')

train_dataloader = datamodule.train_dataloader()

print('Batch Size:', train_dataloader.batch_size)

for sample in iter(train_dataloader):
    print('Shape Images in batch :' ,sample['images'].shape)
    print('Nviews:', sample['nviews'])
    print('Labels: ', sample['label'])
    print('Paths: ' ,sample['paths'])
# Out:
# Options in DataModule {}
# num clases = 3
# len total trainset =   234
# len total testset =   64
# ['1a', '2a', '3a']
# {'1a': 0, '2a': 1, '3a': 2}
# batch_size in FruitDataModule 5
# batch_size in Dataloader train 5
# Batch Size: 5
# Shape Images in batch : torch.Size([65, 3, 250, 250])
# Nviews: [13, 13, 13, 13, 13]
# Labels:  tensor([2, 2, 2, 2, 2])
# Paths:  ['/home/aalbiol/reanotado_3_clases_con_Sara/train/3a/calizblanco_obj0271.cimg', '/home/aalbiol/reanotado_3_clases_con_Sara/train/3a/danoMecanicoobj0021.cimg', '/home/aalbiol/reanotado_3_clases_con_Sara/train/3a/cicatrices_obj0031.cimg', '/home/aalbiol/reanotado_3_clases_con_Sara/train/3a/puntosNegros_obj0109.cimg', '/home/aalbiol/reanotado_3_clases_con_Sara/train/3a/danoMecanicoobj0020.cimg']
# Shape Images in batch : torch.Size([65, 3, 250, 250])
# Nviews: [13, 13, 13, 13, 13]
# Labels:  tensor([0, 1, 2, 1, 1])
# ...
