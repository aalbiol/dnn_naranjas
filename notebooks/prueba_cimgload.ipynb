# %%
import numpy as np
import pycimg
import os
from PIL import Image

# %%
#ruta='/home/aalbiol/owc/mscanData/oranges/naranjasSara/'
fichero2='/Users/aalbiol/noSync/orange_3_clases_1/train/2a/calizblanco_obj0267NEW.cimgz'
clase='bueno'
fichero='obj0000.cimg'

filename=os.path.join(ruta,clase,fichero)
print(filename)
# Out:
# /Users/aalbiol/noSync/orange_3_clases_1/train/2a/calizblanco_obj0267NEW.cimgz/bueno/obj0000.cimg

# %%
#pils=pycimg.cimgread(filename)
pils=pycimg.cimgread(fichero2)

# %%
print(len(pils))
# Out:
# 13

# %%
type(pils[2])
# Out:
# PIL.Image.Image

# %%
pils[11]
# Out:
# <PIL.Image.Image image mode=RGB size=264x254 at 0x7FB0E87039A0>
